# %%
import pandas as pd

print("PROJECT 10 : END-TO-END ML WORKFLOW\n")

workflow = {
    "Step": [
        "Business Problem",
        "Data Collection",
        "Data Cleaning",
        "Exploratory Data Analysis",
        "Feature Selection",
        "Model Training",
        "Model Evaluation",
        "Prediction",
        "Deployment",
        "Ethics & Monitoring"
    ],
    "Description": [
        "Predict customer churn",
        "Collect customer information",
        "Remove missing values and duplicates",
        "Analyze customer behavior",
        "Select useful features",
        "Train ML classification model",
        "Check model accuracy",
        "Predict future churn",
        "Deploy model for business use",
        "Monitor fairness and data privacy"
    ]
}

df = pd.DataFrame(workflow)

print(df)

print("\nFinal Workflow Summary")
print("1. Define Business Problem")
print("2. Collect Data")
print("3. Clean Data")
print("4. Perform EDA")
print("5. Train Machine Learning Model")
print("6. Evaluate Performance")
print("7. Deploy Model")
print("8. Monitor Ethics and Fairness")

print("\nProject 10 Completed Successfully!")
# Out:
# PROJECT 10 : END-TO-END ML WORKFLOW
#
#                         Step                           Description
# 0           Business Problem                Predict customer churn
# 1            Data Collection          Collect customer information
# 2              Data Cleaning  Remove missing values and duplicates
# 3  Exploratory Data Analysis             Analyze customer behavior
# 4          Feature Selection                Select useful features
# 5             Model Training         Train ML classification model
# 6           Model Evaluation                  Check model accuracy
# 7                 Prediction                  Predict future churn
# 8                 Deployment         Deploy model for business use
# 9        Ethics & Monitoring     Monitor fairness and data privacy
#
# Final Workflow Summary
# 1. Define Business Problem
# 2. Collect Data
# 3. Clean Data
# 4. Perform EDA
# 5. Train Machine Learning Model
# 6. Evaluate Performance
# 7. Deploy Model
# ...
